# %% [markdown]
# La heuristica01 se calcula:
# representando en decimal la primera y la ultima
# columna y sumando las representaciones

# %%
def heuristica01(t,n):
    h = 0.0
    p1 = len(t[0])-1
    for d in t[0]:
        h = h + d*10**p1
        p1 = p1 - 1
    p1 = len(t[2])-1
    for d in t[2]:
        h = h + d*10**p1
        p1 = p1 - 1
    n1 = 2.0**n-1.0
    n2 = 54321.0
    return n1*(1.0-h/n2)

# %% [markdown]
# La heuristica02 se calcula: Se suman los elementos de la ultima columna

# %%
def heuristica02(t,n):
    h = 0.0
    for d in t[2]:
        h = h + d
    return (2.0**n-1.0)*(1-h/(n*(n+1)/2))

# %% [markdown]
# La heuristica03 se calcula: Se suman los elementos de las dos ultimas columnas

# %%
def heuristica03(t,n):
    h1 = 0.0
    for d in t[1]:
        h1 = h1 + d
    h2 = 0.0
    for d in t[2]:
        h2 = h2 + d
    h = h1+2.0*h2
    return (2.0**n-1.0)*(1.0-h/(n*(n+1)))

# %%
def heuristica04(t,n):
    h1 = 0.0
    for d in t[1]:
        h1 = h1 + d
    h2 = 0.0
    for d in t[2]:
        h2 = h2 + d
    h = 2.0*h1+3.0*h2
    return (2.0**n-1.0)*(1.0-h/56.0)

# %% [markdown]
# Aquí viene la implementación de A* que usa las heurísticas anteriores

# %%
import copy
inicial=[[5,4,3,2,1],[],[]]
print ("Estado Inicial")
print (inicial)
solucion = []
solucion.append(inicial)
espacio = []
distancia = []
distancia_actual = 0.0
padre_solucion = []
padre_solucion.append(inicial)
padre_espacio = []
final=[[],[],[5,4,3,2,1]]
ind = [[0,1],[0,2],[1,0],[1,2],[2,0],[2,1]]
actual = copy.deepcopy(inicial)
s = 0
iteraciones = 0
while (s==0): 
    print ("Estado Actual")
    print (actual)
    print ("Generando hijos")
    iteraciones = iteraciones + 1
    for i1 in ind:
        nt = copy.deepcopy(actual)
        if nt[i1[0]]:
            t = nt[i1[0]].pop()
            if not nt[i1[1]]:
                nt[i1[1]].append(t)
            else:
                t1 = nt[i1[1]].pop()
                if t1 > t:
                    nt[i1[1]].append(t1)
                    nt[i1[1]].append(t)
                else:
                    nt = []
        else:
            nt = []
        for n in solucion:
            if nt == n:
                nt = []
        for n in espacio:
            if nt == n:
                nt = []
        if nt:
            print ("Hijo ", i1)
            print (nt)
            espacio.append(nt)
            distancia.append(distancia_actual+1.0)
            padre_espacio.append(actual)
    
    print ("Calculando las heuristicas")
    mejor = 0
    hdtotal = 1000000
    index = 0
    if espacio:
        for t in espacio:
            d = distancia[index]
            h = heuristica04(t,5.0)
            hd = h + d
            print( h,d,hd,t)
            if hd < hdtotal:
                hdtotal = hd
                mejor = index
            index = index + 1
        actual = espacio.pop(mejor)
        distancia_actual = distancia.pop(mejor)
        padre_solucion.append(padre_espacio.pop(mejor))
        solucion.append(actual)
    else:
        s = 5
    if actual == final:
        s = 5
ruta = []
t=solucion.pop()
ruta.append(t)
tp = padre_solucion.pop()
while (tp!=inicial):
    ruta.insert(0,tp)
    i1 = solucion.index(tp)
    t = solucion.pop(i1)
    tp = padre_solucion.pop(i1)
ruta.insert(0,inicial)
print ("Solucion")
n1 = 0
for n in ruta:
    print (n1, n)
    n1 = n1 +1
print ("Iteraciones = ")
print (iteraciones)
# Out:
# Estado Inicial
# [[5, 4, 3, 2, 1], [], []]
# Estado Actual
# [[5, 4, 3, 2, 1], [], []]
# Generando hijos
# Hijo  [0, 1]
# [[5, 4, 3, 2], [1], []]
# Hijo  [0, 2]
# [[5, 4, 3, 2], [], [1]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 29.33928571428571 1.0 30.33928571428571 [[5, 4, 3, 2], [], [1]]
# Estado Actual
# [[5, 4, 3, 2], [], [1]]
# Generando hijos
# Hijo  [0, 1]
# [[5, 4, 3], [2], [1]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 27.125 2.0 29.125 [[5, 4, 3], [2], [1]]
# Estado Actual
# [[5, 4, 3], [2], [1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 4, 3, 1], [2], []]
# Hijo  [2, 1]
# [[5, 4, 3], [2, 1], []]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 27.67857142857143 3.0 30.67857142857143 [[5, 4, 3], [2, 1], []]
# Estado Actual
# [[5, 4, 3], [2, 1], []]
# Generando hijos
# Hijo  [0, 2]
# [[5, 4], [2, 1], [3]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 22.696428571428573 4.0 26.696428571428573 [[5, 4], [2, 1], [3]]
# Estado Actual
# [[5, 4], [2, 1], [3]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 4, 1], [2], [3]]
# Hijo  [1, 2]
# [[5, 4], [2], [3, 1]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 23.803571428571427 5.0 28.803571428571427 [[5, 4, 1], [2], [3]]
# 22.142857142857142 5.0 27.142857142857142 [[5, 4], [2], [3, 1]]
# Estado Actual
# [[5, 4], [2], [3, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 4, 2], [], [3, 1]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 23.803571428571427 5.0 28.803571428571427 [[5, 4, 1], [2], [3]]
# 24.357142857142858 6.0 30.357142857142858 [[5, 4, 2], [], [3, 1]]
# Estado Actual
# [[5, 4, 1], [2], [3]]
# Generando hijos
# Hijo  [1, 2]
# [[5, 4, 1], [], [3, 2]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.357142857142858 6.0 30.357142857142858 [[5, 4, 2], [], [3, 1]]
# 22.696428571428573 6.0 28.696428571428573 [[5, 4, 1], [], [3, 2]]
# Estado Actual
# [[5, 4, 1], [], [3, 2]]
# Generando hijos
# Hijo  [0, 1]
# [[5, 4], [1], [3, 2]]
# Hijo  [0, 2]
# [[5, 4], [], [3, 2, 1]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.357142857142858 6.0 30.357142857142858 [[5, 4, 2], [], [3, 1]]
# 21.58928571428571 7.0 28.58928571428571 [[5, 4], [1], [3, 2]]
# 21.03571428571429 7.0 28.03571428571429 [[5, 4], [], [3, 2, 1]]
# Estado Actual
# [[5, 4], [], [3, 2, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[5], [4], [3, 2, 1]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.357142857142858 6.0 30.357142857142858 [[5, 4, 2], [], [3, 1]]
# 21.58928571428571 7.0 28.58928571428571 [[5, 4], [1], [3, 2]]
# 16.607142857142858 8.0 24.607142857142858 [[5], [4], [3, 2, 1]]
# Estado Actual
# [[5], [4], [3, 2, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 1], [4], [3, 2]]
# Hijo  [2, 1]
# [[5], [4, 1], [3, 2]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.357142857142858 6.0 30.357142857142858 [[5, 4, 2], [], [3, 1]]
# 21.58928571428571 7.0 28.58928571428571 [[5, 4], [1], [3, 2]]
# 18.267857142857142 9.0 27.267857142857142 [[5, 1], [4], [3, 2]]
# 17.16071428571429 9.0 26.16071428571429 [[5], [4, 1], [3, 2]]
# Estado Actual
# [[5], [4, 1], [3, 2]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 2], [4, 1], [3]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.357142857142858 6.0 30.357142857142858 [[5, 4, 2], [], [3, 1]]
# 21.58928571428571 7.0 28.58928571428571 [[5, 4], [1], [3, 2]]
# 18.267857142857142 9.0 27.267857142857142 [[5, 1], [4], [3, 2]]
# 20.482142857142858 10.0 30.482142857142858 [[5, 2], [4, 1], [3]]
# Estado Actual
# [[5, 1], [4], [3, 2]]
# Generando hijos
# Hijo  [2, 1]
# [[5, 1], [4, 2], [3]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.357142857142858 6.0 30.357142857142858 [[5, 4, 2], [], [3, 1]]
# 21.58928571428571 7.0 28.58928571428571 [[5, 4], [1], [3, 2]]
# 20.482142857142858 10.0 30.482142857142858 [[5, 2], [4, 1], [3]]
# 19.375 10.0 29.375 [[5, 1], [4, 2], [3]]
# Estado Actual
# [[5, 4], [1], [3, 2]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 4, 2], [1], [3]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.357142857142858 6.0 30.357142857142858 [[5, 4, 2], [], [3, 1]]
# 20.482142857142858 10.0 30.482142857142858 [[5, 2], [4, 1], [3]]
# 19.375 10.0 29.375 [[5, 1], [4, 2], [3]]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# Estado Actual
# [[5, 1], [4, 2], [3]]
# Generando hijos
# Hijo  [0, 1]
# [[5], [4, 2, 1], [3]]
# Hijo  [0, 2]
# [[5], [4, 2], [3, 1]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.357142857142858 6.0 30.357142857142858 [[5, 4, 2], [], [3, 1]]
# 20.482142857142858 10.0 30.482142857142858 [[5, 2], [4, 1], [3]]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 18.267857142857142 11.0 29.267857142857142 [[5], [4, 2, 1], [3]]
# 17.71428571428571 11.0 28.71428571428571 [[5], [4, 2], [3, 1]]
# Estado Actual
# [[5], [4, 2], [3, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 2], [4], [3, 1]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.357142857142858 6.0 30.357142857142858 [[5, 4, 2], [], [3, 1]]
# 20.482142857142858 10.0 30.482142857142858 [[5, 2], [4, 1], [3]]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 18.267857142857142 11.0 29.267857142857142 [[5], [4, 2, 1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# Estado Actual
# [[5], [4, 2, 1], [3]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 3], [4, 2, 1], []]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.357142857142858 6.0 30.357142857142858 [[5, 4, 2], [], [3, 1]]
# 20.482142857142858 10.0 30.482142857142858 [[5, 2], [4, 1], [3]]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# Estado Actual
# [[5, 4, 2], [], [3, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 4, 2, 1], [], [3]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 20.482142857142858 10.0 30.482142857142858 [[5, 2], [4, 1], [3]]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# Estado Actual
# [[5, 2], [4, 1], [3]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 2, 1], [4], [3]]
# Calculando las heuristicas
# 29.892857142857142 1.0 30.892857142857142 [[5, 4, 3, 2], [1], []]
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# Estado Actual
# [[5, 4, 3, 2], [1], []]
# Generando hijos
# Hijo  [0, 2]
# [[5, 4, 3], [1], [2]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 2.0 28.571428571428573 [[5, 4, 3], [1], [2]]
# Estado Actual
# [[5, 4, 3], [1], [2]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 4, 3, 1], [], [2]]
# Hijo  [1, 2]
# [[5, 4, 3], [], [2, 1]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 27.67857142857143 3.0 30.67857142857143 [[5, 4, 3, 1], [], [2]]
# 26.017857142857142 3.0 29.017857142857142 [[5, 4, 3], [], [2, 1]]
# Estado Actual
# [[5, 4, 3], [], [2, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[5, 4], [3], [2, 1]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 27.67857142857143 3.0 30.67857142857143 [[5, 4, 3, 1], [], [2]]
# 22.696428571428573 4.0 26.696428571428573 [[5, 4], [3], [2, 1]]
# Estado Actual
# [[5, 4], [3], [2, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 4, 1], [3], [2]]
# Hijo  [2, 1]
# [[5, 4], [3, 1], [2]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 27.67857142857143 3.0 30.67857142857143 [[5, 4, 3, 1], [], [2]]
# 24.357142857142858 5.0 29.357142857142858 [[5, 4, 1], [3], [2]]
# 23.25 5.0 28.25 [[5, 4], [3, 1], [2]]
# Estado Actual
# [[5, 4], [3, 1], [2]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 4, 2], [3, 1], []]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 27.67857142857143 3.0 30.67857142857143 [[5, 4, 3, 1], [], [2]]
# 24.357142857142858 5.0 29.357142857142858 [[5, 4, 1], [3], [2]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# Estado Actual
# [[5, 4, 1], [3], [2]]
# Generando hijos
# Hijo  [2, 1]
# [[5, 4, 1], [3, 2], []]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 27.67857142857143 3.0 30.67857142857143 [[5, 4, 3, 1], [], [2]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 25.46428571428571 6.0 31.46428571428571 [[5, 4, 1], [3, 2], []]
# Estado Actual
# [[5, 4, 3, 1], [], [2]]
# Generando hijos
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 25.46428571428571 6.0 31.46428571428571 [[5, 4, 1], [3, 2], []]
# Estado Actual
# [[5, 4, 1], [3, 2], []]
# Generando hijos
# Hijo  [0, 1]
# [[5, 4], [3, 2, 1], []]
# Hijo  [0, 2]
# [[5, 4], [3, 2], [1]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 24.357142857142858 7.0 31.357142857142858 [[5, 4], [3, 2, 1], []]
# 23.803571428571427 7.0 30.803571428571427 [[5, 4], [3, 2], [1]]
# Estado Actual
# [[5, 4], [3, 2], [1]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 4, 2], [3], [1]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 24.357142857142858 7.0 31.357142857142858 [[5, 4], [3, 2, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# Estado Actual
# [[5, 4], [3, 2, 1], []]
# Generando hijos
# Hijo  [0, 2]
# [[5], [3, 2, 1], [4]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 17.71428571428571 8.0 25.71428571428571 [[5], [3, 2, 1], [4]]
# Estado Actual
# [[5], [3, 2, 1], [4]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 1], [3, 2], [4]]
# Hijo  [1, 2]
# [[5], [3, 2], [4, 1]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 18.821428571428573 9.0 27.821428571428573 [[5, 1], [3, 2], [4]]
# 17.16071428571429 9.0 26.16071428571429 [[5], [3, 2], [4, 1]]
# Estado Actual
# [[5], [3, 2], [4, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 2], [3], [4, 1]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 18.821428571428573 9.0 27.821428571428573 [[5, 1], [3, 2], [4]]
# 19.375 10.0 29.375 [[5, 2], [3], [4, 1]]
# Estado Actual
# [[5, 1], [3, 2], [4]]
# Generando hijos
# Hijo  [1, 2]
# [[5, 1], [3], [4, 2]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 19.375 10.0 29.375 [[5, 2], [3], [4, 1]]
# 17.71428571428571 10.0 27.71428571428571 [[5, 1], [3], [4, 2]]
# Estado Actual
# [[5, 1], [3], [4, 2]]
# Generando hijos
# Hijo  [0, 1]
# [[5], [3, 1], [4, 2]]
# Hijo  [0, 2]
# [[5], [3], [4, 2, 1]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 19.375 10.0 29.375 [[5, 2], [3], [4, 1]]
# 16.607142857142858 11.0 27.607142857142858 [[5], [3, 1], [4, 2]]
# 16.053571428571427 11.0 27.053571428571427 [[5], [3], [4, 2, 1]]
# Estado Actual
# [[5], [3], [4, 2, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 3], [], [4, 2, 1]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 19.375 10.0 29.375 [[5, 2], [3], [4, 1]]
# 16.607142857142858 11.0 27.607142857142858 [[5], [3, 1], [4, 2]]
# 19.375 12.0 31.375 [[5, 3], [], [4, 2, 1]]
# Estado Actual
# [[5], [3, 1], [4, 2]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 2], [3, 1], [4]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 19.375 10.0 29.375 [[5, 2], [3], [4, 1]]
# 19.375 12.0 31.375 [[5, 3], [], [4, 2, 1]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [3, 1], [4]]
# Estado Actual
# [[5, 2], [3], [4, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 2, 1], [3], [4]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 19.375 12.0 31.375 [[5, 3], [], [4, 2, 1]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [3, 1], [4]]
# 21.03571428571429 11.0 32.03571428571429 [[5, 2, 1], [3], [4]]
# Estado Actual
# [[5, 3], [], [4, 2, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 3, 1], [], [4, 2]]
# Hijo  [2, 1]
# [[5, 3], [1], [4, 2]]
# Calculando las heuristicas
# 28.78571428571429 3.0 31.78571428571429 [[5, 4, 3, 1], [2], []]
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [3, 1], [4]]
# 21.03571428571429 11.0 32.03571428571429 [[5, 2, 1], [3], [4]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# Estado Actual
# [[5, 4, 3, 1], [2], []]
# Generando hijos
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [4], [3, 1]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [3, 1], [4]]
# 21.03571428571429 11.0 32.03571428571429 [[5, 2, 1], [3], [4]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# Estado Actual
# [[5, 2], [4], [3, 1]]
# Generando hijos
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 19.928571428571427 12.0 31.928571428571427 [[5, 2], [3, 1], [4]]
# 21.03571428571429 11.0 32.03571428571429 [[5, 2, 1], [3], [4]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# Estado Actual
# [[5, 2], [3, 1], [4]]
# Generando hijos
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 11.0 32.03571428571429 [[5, 2, 1], [3], [4]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# Estado Actual
# [[5, 2, 1], [3], [4]]
# Generando hijos
# Hijo  [1, 2]
# [[5, 2, 1], [], [4, 3]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 19.375 12.0 31.375 [[5, 2, 1], [], [4, 3]]
# Estado Actual
# [[5, 2, 1], [], [4, 3]]
# Generando hijos
# Hijo  [0, 1]
# [[5, 2], [1], [4, 3]]
# Hijo  [0, 2]
# [[5, 2], [], [4, 3, 1]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 18.267857142857142 13.0 31.267857142857142 [[5, 2], [1], [4, 3]]
# 17.71428571428571 13.0 30.71428571428571 [[5, 2], [], [4, 3, 1]]
# Estado Actual
# [[5, 2], [], [4, 3, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[5], [2], [4, 3, 1]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 18.267857142857142 13.0 31.267857142857142 [[5, 2], [1], [4, 3]]
# 15.5 14.0 29.5 [[5], [2], [4, 3, 1]]
# Estado Actual
# [[5], [2], [4, 3, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 1], [2], [4, 3]]
# Hijo  [2, 1]
# [[5], [2, 1], [4, 3]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 18.267857142857142 13.0 31.267857142857142 [[5, 2], [1], [4, 3]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 16.053571428571427 15.0 31.053571428571427 [[5], [2, 1], [4, 3]]
# Estado Actual
# [[5], [2, 1], [4, 3]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 3], [2, 1], [4]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 18.267857142857142 13.0 31.267857142857142 [[5, 2], [1], [4, 3]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# Estado Actual
# [[5, 2], [1], [4, 3]]
# Generando hijos
# Hijo  [0, 2]
# [[5], [1], [4, 3, 2]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 14.94642857142857 14.0 28.94642857142857 [[5], [1], [4, 3, 2]]
# Estado Actual
# [[5], [1], [4, 3, 2]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 1], [], [4, 3, 2]]
# Hijo  [1, 2]
# [[5], [], [4, 3, 2, 1]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 16.053571428571427 15.0 31.053571428571427 [[5, 1], [], [4, 3, 2]]
# 14.392857142857144 15.0 29.392857142857146 [[5], [], [4, 3, 2, 1]]
# Estado Actual
# [[5], [], [4, 3, 2, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[], [5], [4, 3, 2, 1]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 16.053571428571427 15.0 31.053571428571427 [[5, 1], [], [4, 3, 2]]
# 8.857142857142856 16.0 24.857142857142854 [[], [5], [4, 3, 2, 1]]
# Estado Actual
# [[], [5], [4, 3, 2, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[1], [5], [4, 3, 2]]
# Hijo  [2, 1]
# [[], [5, 1], [4, 3, 2]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 16.053571428571427 15.0 31.053571428571427 [[5, 1], [], [4, 3, 2]]
# 10.517857142857144 17.0 27.517857142857146 [[1], [5], [4, 3, 2]]
# 9.410714285714286 17.0 26.410714285714285 [[], [5, 1], [4, 3, 2]]
# Estado Actual
# [[], [5, 1], [4, 3, 2]]
# Generando hijos
# Hijo  [2, 0]
# [[2], [5, 1], [4, 3]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 16.053571428571427 15.0 31.053571428571427 [[5, 1], [], [4, 3, 2]]
# 10.517857142857144 17.0 27.517857142857146 [[1], [5], [4, 3, 2]]
# 12.732142857142856 18.0 30.732142857142854 [[2], [5, 1], [4, 3]]
# Estado Actual
# [[1], [5], [4, 3, 2]]
# Generando hijos
# Hijo  [2, 1]
# [[1], [5, 2], [4, 3]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 16.053571428571427 15.0 31.053571428571427 [[5, 1], [], [4, 3, 2]]
# 12.732142857142856 18.0 30.732142857142854 [[2], [5, 1], [4, 3]]
# 11.625 18.0 29.625 [[1], [5, 2], [4, 3]]
# Estado Actual
# [[1], [5, 2], [4, 3]]
# Generando hijos
# Hijo  [0, 1]
# [[], [5, 2, 1], [4, 3]]
# Hijo  [0, 2]
# [[], [5, 2], [4, 3, 1]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 16.053571428571427 15.0 31.053571428571427 [[5, 1], [], [4, 3, 2]]
# 12.732142857142856 18.0 30.732142857142854 [[2], [5, 1], [4, 3]]
# 10.517857142857144 19.0 29.517857142857146 [[], [5, 2, 1], [4, 3]]
# 9.964285714285714 19.0 28.964285714285715 [[], [5, 2], [4, 3, 1]]
# Estado Actual
# [[], [5, 2], [4, 3, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[2], [5], [4, 3, 1]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 16.053571428571427 15.0 31.053571428571427 [[5, 1], [], [4, 3, 2]]
# 12.732142857142856 18.0 30.732142857142854 [[2], [5, 1], [4, 3]]
# 10.517857142857144 19.0 29.517857142857146 [[], [5, 2, 1], [4, 3]]
# 12.17857142857143 20.0 32.17857142857143 [[2], [5], [4, 3, 1]]
# Estado Actual
# [[], [5, 2, 1], [4, 3]]
# Generando hijos
# Hijo  [2, 0]
# [[3], [5, 2, 1], [4]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 16.053571428571427 15.0 31.053571428571427 [[5, 1], [], [4, 3, 2]]
# 12.732142857142856 18.0 30.732142857142854 [[2], [5, 1], [4, 3]]
# 12.17857142857143 20.0 32.17857142857143 [[2], [5], [4, 3, 1]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# Estado Actual
# [[2], [5, 1], [4, 3]]
# Generando hijos
# Hijo  [1, 0]
# [[2, 1], [5], [4, 3]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 16.053571428571427 15.0 31.053571428571427 [[5, 1], [], [4, 3, 2]]
# 12.17857142857143 20.0 32.17857142857143 [[2], [5], [4, 3, 1]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 13.839285714285714 19.0 32.839285714285715 [[2, 1], [5], [4, 3]]
# Estado Actual
# [[5, 1], [], [4, 3, 2]]
# Generando hijos
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 17.16071428571429 15.0 32.16071428571429 [[5, 1], [2], [4, 3]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 12.17857142857143 20.0 32.17857142857143 [[2], [5], [4, 3, 1]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 13.839285714285714 19.0 32.839285714285715 [[2, 1], [5], [4, 3]]
# Estado Actual
# [[5, 1], [2], [4, 3]]
# Generando hijos
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 12.17857142857143 20.0 32.17857142857143 [[2], [5], [4, 3, 1]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 13.839285714285714 19.0 32.839285714285715 [[2, 1], [5], [4, 3]]
# Estado Actual
# [[2], [5], [4, 3, 1]]
# Generando hijos
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.571428571428573 6.0 32.57142857142857 [[5, 4, 2], [3, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 13.839285714285714 19.0 32.839285714285715 [[2, 1], [5], [4, 3]]
# Estado Actual
# [[5, 4, 2], [3, 1], []]
# Generando hijos
# Hijo  [1, 0]
# [[5, 4, 2, 1], [3], []]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 21.58928571428571 11.0 32.58928571428571 [[5, 2, 1], [4], [3]]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 13.839285714285714 19.0 32.839285714285715 [[2, 1], [5], [4, 3]]
# 27.67857142857143 7.0 34.67857142857143 [[5, 4, 2, 1], [3], []]
# Estado Actual
# [[5, 2, 1], [4], [3]]
# Generando hijos
# Hijo  [2, 1]
# [[5, 2, 1], [4, 3], []]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 13.839285714285714 19.0 32.839285714285715 [[2, 1], [5], [4, 3]]
# 27.67857142857143 7.0 34.67857142857143 [[5, 4, 2, 1], [3], []]
# 23.25 12.0 35.25 [[5, 2, 1], [4, 3], []]
# Estado Actual
# [[2, 1], [5], [4, 3]]
# Generando hijos
# Hijo  [2, 1]
# [[2, 1], [5, 3], [4]]
# Calculando las heuristicas
# 24.91071428571429 8.0 32.91071428571429 [[5, 4, 2], [1], [3]]
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 27.67857142857143 7.0 34.67857142857143 [[5, 4, 2, 1], [3], []]
# 23.25 12.0 35.25 [[5, 2, 1], [4, 3], []]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# Estado Actual
# [[5, 4, 2], [1], [3]]
# Generando hijos
# Calculando las heuristicas
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 19.928571428571427 13.0 32.92857142857143 [[5, 3], [1], [4, 2]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 27.67857142857143 7.0 34.67857142857143 [[5, 4, 2, 1], [3], []]
# 23.25 12.0 35.25 [[5, 2, 1], [4, 3], []]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# Estado Actual
# [[5, 3], [1], [4, 2]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 3, 2], [1], [4]]
# Calculando las heuristicas
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 7.0 33.01785714285714 [[5, 4, 2, 1], [], [3]]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 27.67857142857143 7.0 34.67857142857143 [[5, 4, 2, 1], [3], []]
# 23.25 12.0 35.25 [[5, 2, 1], [4, 3], []]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# 23.25 14.0 37.25 [[5, 3, 2], [1], [4]]
# Estado Actual
# [[5, 4, 2, 1], [], [3]]
# Generando hijos
# Calculando las heuristicas
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 26.017857142857142 8.0 34.01785714285714 [[5, 4, 2], [3], [1]]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 27.67857142857143 7.0 34.67857142857143 [[5, 4, 2, 1], [3], []]
# 23.25 12.0 35.25 [[5, 2, 1], [4, 3], []]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# 23.25 14.0 37.25 [[5, 3, 2], [1], [4]]
# Estado Actual
# [[5, 4, 2], [3], [1]]
# Generando hijos
# Calculando las heuristicas
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 21.03571428571429 13.0 34.03571428571429 [[5, 3, 1], [], [4, 2]]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 27.67857142857143 7.0 34.67857142857143 [[5, 4, 2, 1], [3], []]
# 23.25 12.0 35.25 [[5, 2, 1], [4, 3], []]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# 23.25 14.0 37.25 [[5, 3, 2], [1], [4]]
# Estado Actual
# [[5, 3, 1], [], [4, 2]]
# Generando hijos
# Hijo  [2, 1]
# [[5, 3, 1], [2], [4]]
# Calculando las heuristicas
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 27.67857142857143 7.0 34.67857142857143 [[5, 4, 2, 1], [3], []]
# 23.25 12.0 35.25 [[5, 2, 1], [4, 3], []]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# 23.25 14.0 37.25 [[5, 3, 2], [1], [4]]
# 22.142857142857142 14.0 36.14285714285714 [[5, 3, 1], [2], [4]]
# Estado Actual
# [[5, 4, 2, 1], [3], []]
# Generando hijos
# Calculando las heuristicas
# 23.25 12.0 35.25 [[5, 3], [4, 2, 1], []]
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 23.25 12.0 35.25 [[5, 2, 1], [4, 3], []]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# 23.25 14.0 37.25 [[5, 3, 2], [1], [4]]
# 22.142857142857142 14.0 36.14285714285714 [[5, 3, 1], [2], [4]]
# Estado Actual
# [[5, 3], [4, 2, 1], []]
# Generando hijos
# Hijo  [1, 0]
# [[5, 3, 1], [4, 2], []]
# Hijo  [1, 2]
# [[5, 3], [4, 2], [1]]
# Calculando las heuristicas
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 23.25 12.0 35.25 [[5, 2, 1], [4, 3], []]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# 23.25 14.0 37.25 [[5, 3, 2], [1], [4]]
# 22.142857142857142 14.0 36.14285714285714 [[5, 3, 1], [2], [4]]
# 24.357142857142858 13.0 37.35714285714286 [[5, 3, 1], [4, 2], []]
# 22.696428571428573 13.0 35.69642857142857 [[5, 3], [4, 2], [1]]
# Estado Actual
# [[5, 2, 1], [4, 3], []]
# Generando hijos
# Hijo  [0, 1]
# [[5, 2], [4, 3, 1], []]
# Hijo  [0, 2]
# [[5, 2], [4, 3], [1]]
# Calculando las heuristicas
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# 23.25 14.0 37.25 [[5, 3, 2], [1], [4]]
# 22.142857142857142 14.0 36.14285714285714 [[5, 3, 1], [2], [4]]
# 24.357142857142858 13.0 37.35714285714286 [[5, 3, 1], [4, 2], []]
# 22.696428571428573 13.0 35.69642857142857 [[5, 3], [4, 2], [1]]
# 22.142857142857142 13.0 35.14285714285714 [[5, 2], [4, 3, 1], []]
# 21.58928571428571 13.0 34.58928571428571 [[5, 2], [4, 3], [1]]
# Estado Actual
# [[5, 2], [4, 3], [1]]
# Generando hijos
# Hijo  [0, 1]
# [[5], [4, 3, 2], [1]]
# Calculando las heuristicas
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# 23.25 14.0 37.25 [[5, 3, 2], [1], [4]]
# 22.142857142857142 14.0 36.14285714285714 [[5, 3, 1], [2], [4]]
# 24.357142857142858 13.0 37.35714285714286 [[5, 3, 1], [4, 2], []]
# 22.696428571428573 13.0 35.69642857142857 [[5, 3], [4, 2], [1]]
# 22.142857142857142 13.0 35.14285714285714 [[5, 2], [4, 3, 1], []]
# 19.375 14.0 33.375 [[5], [4, 3, 2], [1]]
# Estado Actual
# [[5], [4, 3, 2], [1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 1], [4, 3, 2], []]
# Hijo  [2, 1]
# [[5], [4, 3, 2, 1], []]
# Calculando las heuristicas
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# 23.25 14.0 37.25 [[5, 3, 2], [1], [4]]
# 22.142857142857142 14.0 36.14285714285714 [[5, 3, 1], [2], [4]]
# 24.357142857142858 13.0 37.35714285714286 [[5, 3, 1], [4, 2], []]
# 22.696428571428573 13.0 35.69642857142857 [[5, 3], [4, 2], [1]]
# 22.142857142857142 13.0 35.14285714285714 [[5, 2], [4, 3, 1], []]
# 21.03571428571429 15.0 36.03571428571429 [[5, 1], [4, 3, 2], []]
# 19.928571428571427 15.0 34.92857142857143 [[5], [4, 3, 2, 1], []]
# Estado Actual
# [[5], [4, 3, 2, 1], []]
# Generando hijos
# Hijo  [0, 2]
# [[], [4, 3, 2, 1], [5]]
# Calculando las heuristicas
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# 23.25 14.0 37.25 [[5, 3, 2], [1], [4]]
# 22.142857142857142 14.0 36.14285714285714 [[5, 3, 1], [2], [4]]
# 24.357142857142858 13.0 37.35714285714286 [[5, 3, 1], [4, 2], []]
# 22.696428571428573 13.0 35.69642857142857 [[5, 3], [4, 2], [1]]
# 22.142857142857142 13.0 35.14285714285714 [[5, 2], [4, 3, 1], []]
# 21.03571428571429 15.0 36.03571428571429 [[5, 1], [4, 3, 2], []]
# 11.625 16.0 27.625 [[], [4, 3, 2, 1], [5]]
# Estado Actual
# [[], [4, 3, 2, 1], [5]]
# Generando hijos
# Hijo  [1, 0]
# [[1], [4, 3, 2], [5]]
# Hijo  [1, 2]
# [[], [4, 3, 2], [5, 1]]
# Calculando las heuristicas
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# 23.25 14.0 37.25 [[5, 3, 2], [1], [4]]
# 22.142857142857142 14.0 36.14285714285714 [[5, 3, 1], [2], [4]]
# 24.357142857142858 13.0 37.35714285714286 [[5, 3, 1], [4, 2], []]
# 22.696428571428573 13.0 35.69642857142857 [[5, 3], [4, 2], [1]]
# 22.142857142857142 13.0 35.14285714285714 [[5, 2], [4, 3, 1], []]
# 21.03571428571429 15.0 36.03571428571429 [[5, 1], [4, 3, 2], []]
# 12.732142857142856 17.0 29.732142857142854 [[1], [4, 3, 2], [5]]
# 11.07142857142857 17.0 28.07142857142857 [[], [4, 3, 2], [5, 1]]
# Estado Actual
# [[], [4, 3, 2], [5, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[2], [4, 3], [5, 1]]
# Calculando las heuristicas
# 21.03571428571429 16.0 37.03571428571429 [[5, 3], [2, 1], [4]]
# 15.5 20.0 35.5 [[3], [5, 2, 1], [4]]
# 15.5 20.0 35.5 [[2, 1], [5, 3], [4]]
# 23.25 14.0 37.25 [[5, 3, 2], [1], [4]]
# 22.142857142857142 14.0 36.14285714285714 [[5, 3, 1], [2], [4]]
# 24.357142857142858 13.0 37.35714285714286 [[5, 3, 1], [4, 2], []]
# 22.696428571428573 13.0 35.69642857142857 [[5, 3], [4, 2], [1]]
# ...
# [[3], [4, 2], [5, 1]]
# Calculando las heuristicas
# 14.94642857142857 24.0 38.94642857142857 [[3], [4, 2, 1], [5]]
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [4, 1], [5]]
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 24.91071428571429 14.0 38.91071428571429 [[5, 3, 2], [4], [1]]
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [5], [4, 1]]
# 22.696428571428573 16.0 38.69642857142857 [[5, 3, 2], [], [4, 1]]
# 14.392857142857144 25.0 39.392857142857146 [[4, 1], [], [5, 3, 2]]
# 13.285714285714286 25.0 38.285714285714285 [[4], [1], [5, 3, 2]]
# 24.357142857142858 15.0 39.35714285714286 [[5, 3, 2, 1], [], [4]]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 14.392857142857144 23.0 37.392857142857146 [[3], [4, 2], [5, 1]]
# Estado Actual
# [[3], [4, 2], [5, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[3, 2], [4], [5, 1]]
# Calculando las heuristicas
# 14.94642857142857 24.0 38.94642857142857 [[3], [4, 2, 1], [5]]
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [4, 1], [5]]
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 24.91071428571429 14.0 38.91071428571429 [[5, 3, 2], [4], [1]]
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [5], [4, 1]]
# 22.696428571428573 16.0 38.69642857142857 [[5, 3, 2], [], [4, 1]]
# 14.392857142857144 25.0 39.392857142857146 [[4, 1], [], [5, 3, 2]]
# 13.285714285714286 25.0 38.285714285714285 [[4], [1], [5, 3, 2]]
# 24.357142857142858 15.0 39.35714285714286 [[5, 3, 2, 1], [], [4]]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 24.0 40.60714285714286 [[3, 2], [4], [5, 1]]
# Estado Actual
# [[4], [1], [5, 3, 2]]
# Generando hijos
# Hijo  [2, 0]
# [[4, 2], [1], [5, 3]]
# Calculando las heuristicas
# 14.94642857142857 24.0 38.94642857142857 [[3], [4, 2, 1], [5]]
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [4, 1], [5]]
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 24.91071428571429 14.0 38.91071428571429 [[5, 3, 2], [4], [1]]
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [5], [4, 1]]
# 22.696428571428573 16.0 38.69642857142857 [[5, 3, 2], [], [4, 1]]
# 14.392857142857144 25.0 39.392857142857146 [[4, 1], [], [5, 3, 2]]
# 24.357142857142858 15.0 39.35714285714286 [[5, 3, 2, 1], [], [4]]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 24.0 40.60714285714286 [[3, 2], [4], [5, 1]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# Estado Actual
# [[5, 3, 2], [], [4, 1]]
# Generando hijos
# Calculando las heuristicas
# 14.94642857142857 24.0 38.94642857142857 [[3], [4, 2, 1], [5]]
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [4, 1], [5]]
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 24.91071428571429 14.0 38.91071428571429 [[5, 3, 2], [4], [1]]
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [5], [4, 1]]
# 14.392857142857144 25.0 39.392857142857146 [[4, 1], [], [5, 3, 2]]
# 24.357142857142858 15.0 39.35714285714286 [[5, 3, 2, 1], [], [4]]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 24.0 40.60714285714286 [[3, 2], [4], [5, 1]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# Estado Actual
# [[5, 3, 2], [4], [1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 3, 2, 1], [4], []]
# Calculando las heuristicas
# 14.94642857142857 24.0 38.94642857142857 [[3], [4, 2, 1], [5]]
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [4, 1], [5]]
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [5], [4, 1]]
# 14.392857142857144 25.0 39.392857142857146 [[4, 1], [], [5, 3, 2]]
# 24.357142857142858 15.0 39.35714285714286 [[5, 3, 2, 1], [], [4]]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 24.0 40.60714285714286 [[3, 2], [4], [5, 1]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# Estado Actual
# [[3], [4, 2, 1], [5]]
# Generando hijos
# Calculando las heuristicas
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [4, 1], [5]]
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [5], [4, 1]]
# 14.392857142857144 25.0 39.392857142857146 [[4, 1], [], [5, 3, 2]]
# 24.357142857142858 15.0 39.35714285714286 [[5, 3, 2, 1], [], [4]]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 24.0 40.60714285714286 [[3, 2], [4], [5, 1]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# Estado Actual
# [[3, 2], [4, 1], [5]]
# Generando hijos
# Hijo  [1, 0]
# [[3, 2, 1], [4], [5]]
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 17.16071428571429 22.0 39.16071428571429 [[3, 2], [5], [4, 1]]
# 14.392857142857144 25.0 39.392857142857146 [[4, 1], [], [5, 3, 2]]
# 24.357142857142858 15.0 39.35714285714286 [[5, 3, 2, 1], [], [4]]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 24.0 40.60714285714286 [[3, 2], [4], [5, 1]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.267857142857142 23.0 41.26785714285714 [[3, 2, 1], [4], [5]]
# Estado Actual
# [[3, 2], [5], [4, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[3, 2, 1], [5], [4]]
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 14.392857142857144 25.0 39.392857142857146 [[4, 1], [], [5, 3, 2]]
# 24.357142857142858 15.0 39.35714285714286 [[5, 3, 2, 1], [], [4]]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 24.0 40.60714285714286 [[3, 2], [4], [5, 1]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.267857142857142 23.0 41.26785714285714 [[3, 2, 1], [4], [5]]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# Estado Actual
# [[5, 3, 2, 1], [], [4]]
# Generando hijos
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 14.392857142857144 25.0 39.392857142857146 [[4, 1], [], [5, 3, 2]]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 24.0 40.60714285714286 [[3, 2], [4], [5, 1]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.267857142857142 23.0 41.26785714285714 [[3, 2, 1], [4], [5]]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# Estado Actual
# [[4, 1], [], [5, 3, 2]]
# Generando hijos
# Hijo  [2, 1]
# [[4, 1], [2], [5, 3]]
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 24.0 40.60714285714286 [[3, 2], [4], [5, 1]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.267857142857142 23.0 41.26785714285714 [[3, 2, 1], [4], [5]]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# 15.5 26.0 41.5 [[4, 1], [2], [5, 3]]
# Estado Actual
# [[3, 2], [4], [5, 1]]
# Generando hijos
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.267857142857142 23.0 41.26785714285714 [[3, 2, 1], [4], [5]]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# 15.5 26.0 41.5 [[4, 1], [2], [5, 3]]
# Estado Actual
# [[3, 2, 1], [4], [5]]
# Generando hijos
# Hijo  [1, 2]
# [[3, 2, 1], [], [5, 4]]
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# 15.5 26.0 41.5 [[4, 1], [2], [5, 3]]
# 16.053571428571427 24.0 40.05357142857143 [[3, 2, 1], [], [5, 4]]
# Estado Actual
# [[3, 2, 1], [], [5, 4]]
# Generando hijos
# Hijo  [0, 1]
# [[3, 2], [1], [5, 4]]
# Hijo  [0, 2]
# [[3, 2], [], [5, 4, 1]]
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# 15.5 26.0 41.5 [[4, 1], [2], [5, 3]]
# 14.94642857142857 25.0 39.94642857142857 [[3, 2], [1], [5, 4]]
# 14.392857142857144 25.0 39.392857142857146 [[3, 2], [], [5, 4, 1]]
# Estado Actual
# [[3, 2], [], [5, 4, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[3], [2], [5, 4, 1]]
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# 15.5 26.0 41.5 [[4, 1], [2], [5, 3]]
# 14.94642857142857 25.0 39.94642857142857 [[3, 2], [1], [5, 4]]
# 12.17857142857143 26.0 38.17857142857143 [[3], [2], [5, 4, 1]]
# Estado Actual
# [[3], [2], [5, 4, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[3, 1], [2], [5, 4]]
# Hijo  [2, 1]
# [[3], [2, 1], [5, 4]]
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# 15.5 26.0 41.5 [[4, 1], [2], [5, 3]]
# 14.94642857142857 25.0 39.94642857142857 [[3, 2], [1], [5, 4]]
# 13.839285714285714 27.0 40.839285714285715 [[3, 1], [2], [5, 4]]
# 12.732142857142856 27.0 39.732142857142854 [[3], [2, 1], [5, 4]]
# Estado Actual
# [[3], [2, 1], [5, 4]]
# Generando hijos
# Hijo  [0, 2]
# [[], [2, 1], [5, 4, 3]]
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# 15.5 26.0 41.5 [[4, 1], [2], [5, 3]]
# 14.94642857142857 25.0 39.94642857142857 [[3, 2], [1], [5, 4]]
# 13.839285714285714 27.0 40.839285714285715 [[3, 1], [2], [5, 4]]
# 7.75 28.0 35.75 [[], [2, 1], [5, 4, 3]]
# Estado Actual
# [[], [2, 1], [5, 4, 3]]
# Generando hijos
# Hijo  [1, 0]
# [[1], [2], [5, 4, 3]]
# Hijo  [1, 2]
# [[], [2], [5, 4, 3, 1]]
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# 15.5 26.0 41.5 [[4, 1], [2], [5, 3]]
# 14.94642857142857 25.0 39.94642857142857 [[3, 2], [1], [5, 4]]
# 13.839285714285714 27.0 40.839285714285715 [[3, 1], [2], [5, 4]]
# 8.857142857142856 29.0 37.857142857142854 [[1], [2], [5, 4, 3]]
# 7.19642857142857 29.0 36.19642857142857 [[], [2], [5, 4, 3, 1]]
# Estado Actual
# [[], [2], [5, 4, 3, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[2], [], [5, 4, 3, 1]]
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# 15.5 26.0 41.5 [[4, 1], [2], [5, 3]]
# 14.94642857142857 25.0 39.94642857142857 [[3, 2], [1], [5, 4]]
# 13.839285714285714 27.0 40.839285714285715 [[3, 1], [2], [5, 4]]
# 8.857142857142856 29.0 37.857142857142854 [[1], [2], [5, 4, 3]]
# 9.410714285714286 30.0 39.410714285714285 [[2], [], [5, 4, 3, 1]]
# Estado Actual
# [[1], [2], [5, 4, 3]]
# Generando hijos
# Hijo  [1, 2]
# [[1], [], [5, 4, 3, 2]]
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# 15.5 26.0 41.5 [[4, 1], [2], [5, 3]]
# 14.94642857142857 25.0 39.94642857142857 [[3, 2], [1], [5, 4]]
# 13.839285714285714 27.0 40.839285714285715 [[3, 1], [2], [5, 4]]
# 9.410714285714286 30.0 39.410714285714285 [[2], [], [5, 4, 3, 1]]
# 7.75 30.0 37.75 [[1], [], [5, 4, 3, 2]]
# Estado Actual
# [[1], [], [5, 4, 3, 2]]
# Generando hijos
# Hijo  [0, 1]
# [[], [1], [5, 4, 3, 2]]
# Hijo  [0, 2]
# [[], [], [5, 4, 3, 2, 1]]
# Calculando las heuristicas
# 18.821428571428573 24.0 42.82142857142857 [[4], [5, 3, 2, 1], []]
# 25.46428571428571 16.0 41.46428571428571 [[5, 3, 2], [4, 1], []]
# 17.71428571428571 24.0 41.71428571428571 [[3, 2], [5, 1], [4]]
# 16.607142857142858 26.0 42.60714285714286 [[4, 2], [1], [5, 3]]
# 26.571428571428573 15.0 41.57142857142857 [[5, 3, 2, 1], [4], []]
# 18.821428571428573 23.0 41.82142857142857 [[3, 2, 1], [5], [4]]
# 15.5 26.0 41.5 [[4, 1], [2], [5, 3]]
# 14.94642857142857 25.0 39.94642857142857 [[3, 2], [1], [5, 4]]
# 13.839285714285714 27.0 40.839285714285715 [[3, 1], [2], [5, 4]]
# 9.410714285714286 30.0 39.410714285714285 [[2], [], [5, 4, 3, 1]]
# 6.642857142857143 31.0 37.642857142857146 [[], [1], [5, 4, 3, 2]]
# 6.0892857142857135 31.0 37.089285714285715 [[], [], [5, 4, 3, 2, 1]]
# Solucion
# 0 [[5, 4, 3, 2, 1], [], []]
# 1 [[5, 4, 3, 2], [], [1]]
# 2 [[5, 4, 3], [2], [1]]
# 3 [[5, 4, 3], [2, 1], []]
# 4 [[5, 4], [2, 1], [3]]
# 5 [[5, 4, 1], [2], [3]]
# 6 [[5, 4, 1], [], [3, 2]]
# 7 [[5, 4], [], [3, 2, 1]]
# 8 [[5], [4], [3, 2, 1]]
# 9 [[5], [4, 1], [3, 2]]
# 10 [[5, 2], [4, 1], [3]]
# 11 [[5, 2, 1], [4], [3]]
# 12 [[5, 2, 1], [4, 3], []]
# 13 [[5, 2], [4, 3], [1]]
# 14 [[5], [4, 3, 2], [1]]
# 15 [[5], [4, 3, 2, 1], []]
# 16 [[], [4, 3, 2, 1], [5]]
# 17 [[1], [4, 3, 2], [5]]
# 18 [[1], [4, 3], [5, 2]]
# 19 [[], [4, 3], [5, 2, 1]]
# 20 [[3], [4], [5, 2, 1]]
# 21 [[3], [4, 1], [5, 2]]
# 22 [[3, 2], [4, 1], [5]]
# 23 [[3, 2, 1], [4], [5]]
# 24 [[3, 2, 1], [], [5, 4]]
# 25 [[3, 2], [], [5, 4, 1]]
# 26 [[3], [2], [5, 4, 1]]
# 27 [[3], [2, 1], [5, 4]]
# 28 [[], [2, 1], [5, 4, 3]]
# 29 [[1], [2], [5, 4, 3]]
# 30 [[1], [], [5, 4, 3, 2]]
# 31 [[], [], [5, 4, 3, 2, 1]]
# Iteraciones =
# 142

# %% [markdown]
# TERMINÓ!!!!!
